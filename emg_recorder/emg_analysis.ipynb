# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
raw_data = np.load('data/emg_data.npy')

# %%
raw_data[:,0].shape[0] / 20
# Out:
# 61.8

# %%
plt.plot(raw_data[:,0])

# %%
raw_data_ninapro = loadmat('../Ninapro_DB5/s1/S1_E1_A1.mat')

# %%
plt.plot(raw_data_ninapro['emg'][:, 0][:1000])

# %%
plt.plot(raw_data_ninapro['stimulus'][1900:2650])

# %%
(2650 - 1900) / 3
# Out:
# 250.0
